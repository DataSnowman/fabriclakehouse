# %% [markdown]
# **Create Table**

# %%
# %%sql
# create table deltademosparksql (id int) USING DELTA;
#
# INSERT into deltademosparksql VALUES (0);
# INSERT into deltademosparksql VALUES (1);
# INSERT into deltademosparksql VALUES (2);
# INSERT into deltademosparksql VALUES (3);
# INSERT into deltademosparksql VALUES (4);
# Out:
# StatementMeta(, 1f7dbd7b-0dc9-4c30-b13e-0bffe8a0bb09, -1, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# This is away of loading the data as CSV.  Then you could convert to Delta or read the CSV into a dataframe and then write the dataframe as delta (do this in Pyspark)

# %%
# %%sql
#
# create table deltademosparksql (id int) USING CSV LOCATION 'Files/deltaexamples/deltademosparksql1.csv'
# Out:
# StatementMeta(, 4fe25f16-e676-4e34-a31c-3e5e67c9dc9a, 19, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# Read Data

# %%
# %%sql
# -- Orginal Data
#
# SELECT * from deltademosparksql
# Out:
# StatementMeta(, 1f7dbd7b-0dc9-4c30-b13e-0bffe8a0bb09, 11, Finished, Available)
# <Spark SQL result set with 5 rows and 1 fields>

# %%
# %%sql
#
# -- Overwrite could maybe be an update or a delete and insert new
#
# delete from deltademosparksql;
#
# INSERT into deltademosparksql VALUES (5);
# INSERT into deltademosparksql VALUES (6);
# INSERT into deltademosparksql VALUES (7);
# INSERT into deltademosparksql VALUES (8);
# INSERT into deltademosparksql VALUES (9);
# Out:
# StatementMeta(, d52c9e83-03d8-4834-af03-56795681f568, -1, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# -- Read Overwriten Data
#
# SELECT * from deltademosparksql
# Out:
# StatementMeta(, d52c9e83-03d8-4834-af03-56795681f568, 17, Finished, Available)
# <Spark SQL result set with 5 rows and 1 fields>

# %%
# %%sql
#
# --Append (insert data)
# INSERT into deltademosparksql VALUES (11);
# INSERT into deltademosparksql VALUES (12);
# INSERT into deltademosparksql VALUES (13);
# INSERT into deltademosparksql VALUES (14);
# INSERT into deltademosparksql VALUES (15);
# Out:
# StatementMeta(, d52c9e83-03d8-4834-af03-56795681f568, -1, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# -- Read Appended Data
#
# SELECT * from deltademosparksql
# Out:
# StatementMeta(, d52c9e83-03d8-4834-af03-56795681f568, 23, Finished, Available)
# <Spark SQL result set with 10 rows and 1 fields>

# %%
# %%sql
# DESCRIBE HISTORY deltademosparksql
# Out:
# StatementMeta(, d52c9e83-03d8-4834-af03-56795681f568, 25, Finished, Available)
# <Spark SQL result set with 23 rows and 15 fields>

# %%
# %%sql
# -- Time Travel1
# -- Time Travel Spark SQL (lot more versions here with all the inserts)
#
# SELECT * FROM deltademosparksql VERSION AS OF 5
# Out:
# StatementMeta(, d52c9e83-03d8-4834-af03-56795681f568, 31, Finished, Available)
# <Spark SQL result set with 5 rows and 1 fields>

# %%
# %%sql
# -- Time Travel2
# -- Time Travel Spark SQL (lot more versions here with all the inserts)
#
# SELECT * FROM deltademosparksql VERSION AS OF 11
# Out:
# StatementMeta(, d52c9e83-03d8-4834-af03-56795681f568, 32, Finished, Available)
# <Spark SQL result set with 5 rows and 1 fields>
